# %%
pip install flask
# Out:
# Requirement already satisfied: flask in /Users/geethapuroop/Documents/anaconda3/lib/python3.13/site-packages (3.1.2)
# Requirement already satisfied: blinker>=1.9.0 in /Users/geethapuroop/Documents/anaconda3/lib/python3.13/site-packages (from flask) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /Users/geethapuroop/Documents/anaconda3/lib/python3.13/site-packages (from flask) (8.2.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in /Users/geethapuroop/Documents/anaconda3/lib/python3.13/site-packages (from flask) (2.2.0)
# Requirement already satisfied: jinja2>=3.1.2 in /Users/geethapuroop/Documents/anaconda3/lib/python3.13/site-packages (from flask) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /Users/geethapuroop/Documents/anaconda3/lib/python3.13/site-packages (from flask) (3.0.2)
# Requirement already satisfied: werkzeug>=3.1.0 in /Users/geethapuroop/Documents/anaconda3/lib/python3.13/site-packages (from flask) (3.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from flask import Flask, render_template

app = Flask(__name__)

@app.route('/')
def hello_world():
    return render_template('index.html')

if __name__ == '__main__':
    app.run(debug=True, use_reloader=False)

# %%
import os

os.makedirs('templates', exist_ok=True)
with open('templates/index.html', 'w') as f:
    f.write('''<!DOCTYPE html>
<html>
<head><title>Hello World</title></head>
<body>
    <h1>Hello, World!</h1>
    <p>This is my first Flask app for MSAI-631.</p>
</body>
</html>''')
print("Template created.")
# Out:
# Template created.

# %%
import os
print("Current directory:", os.getcwd())
print("Files here:", os.listdir())
print("Templates folder exists:", os.path.exists('templates'))
if os.path.exists('templates'):
    print("Contents of templates:", os.listdir('templates'))

# %%
def get_environment():
    try:
        import google.colab
        return "Google Colab"
    except ImportError:
        pass
    try:
        shell = get_ipython().__class__.__name__
        if shell == 'ZMQInteractiveShell':
            return "Jupyter Notebook/Lab"
        else:
            return shell
    except NameError:
        return "Standard Python interpreter"

print(f"Running in: {get_environment()}")
# Out:
# Running in: Jupyter Notebook/Lab
